# %%
## import library
import pandas as pd

# %%
## import census data and get sample of 15
dfcensus = pd.read_csv("https://raw.githubusercontent.com/sandeepmj/datasets/main/conditional-conversion/NYC_Census_2020_2010_geotype.csv")
dfcensus.head()
# Out:
#    Year GeoType   Borough  Community District Number  \
# 0  2020      CD    Queens                        407
# 1  2020      CD  Brooklyn                        311
# 2  2020      CD    Queens                        404
# 3  2020      CD    Queens                        408
# 4  2020      CD    Queens                        411
#
#           Community District Name Total Population  Average household size  \
# 0     Queens Community District 7          269,587                    2.75
# 1  Brooklyn Community District 11          198,870                    2.94
# 2     Queens Community District 4          181,025                    3.24
# 3     Queens Community District 8          161,402                    2.76
# 4    Queens Community District 11          122,211                    2.69
#
#   Children  Latino White non-Hispanic Black non-Hispanic    Asian Other race  \
# 0   45,543  48,845             55,882              5,412  154,404      1,575
# 1   42,380  31,489             72,496              2,353   86,067      1,081
# 2   38,213  93,972              9,329              7,679   65,963      1,692
# 3   32,754  29,486             44,302             18,682   60,413      3,200
# 4   21,612  14,460             41,967              2,641   59,980        779
#
#   Two or more races Total housing units Occupied housing units  \
# 0             3,469             102,836                 97,059
# 1             5,384              71,074                 67,236
# 2             2,390              57,748                 55,202
# 3             5,319              59,385                 56,623
# 4             2,384              47,357                 45,204
#
#   Vacant housing units
# 0                5,777
# 1                3,838
# 2                2,546
# 3                2,762
# 4                2,153

# %%
# get info
dfcensus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       59 non-null     int64
#  1   GeoType                    59 non-null     object
#  2   Borough                    59 non-null     object
#  3   Community District Number  59 non-null     int64
#  4   Community District Name    59 non-null     object
#  5   Total Population           59 non-null     object
#  6   Average household size     59 non-null     float64
#  7   Children                   59 non-null     object
#  8   Latino                     59 non-null     object
#  9   White non-Hispanic         59 non-null     object
#  10  Black non-Hispanic         59 non-null     object
#  11  Asian                      59 non-null     object
#  12  Other race                 59 non-null     object
#  13  Two or more races          59 non-null     object
#  14  Total housing units        59 non-null     object
#  15  Occupied housing units     59 non-null     object
#  16  Vacant housing units       59 non-null     object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 8.0+ KB

# %%
## import SNAP benefits and see sample of 15
dfsnap = pd.read_csv("https://raw.githubusercontent.com/sandeepmj/datasets/main/conditional-conversion/SNAP_benefits_borough.csv")

# %%
## get info
dfsnap.sample(10)
# Out:
#         Month           Boro Community District  BC_SNAP_Recipients  \
# 1018  12/1/22          Bronx                B04               58250
# 1115   3/1/23         Queens                Q12               50109
# 983    9/1/22       Brooklyn                K16               37145
# 770   12/1/19          Bronx                B07               42103
# 1060  12/1/22  Staten Island                S02               17783
# 458    6/1/22         Queens                Q04               28104
# 233    6/1/21  Staten Island                S01               39842
# 338   12/1/21         Queens                Q02               11571
# 785   12/1/19       Brooklyn                K10               15953
# 25     9/1/20       Brooklyn                K02               14517
#
#       BC_SNAP_Households
# 1018               33662
# 1115               30098
# 983                21909
# 770                24237
# 1060               10311
# 458                16543
# 233                21361
# 338                 7402
# 785                 9536
# 25                  9883

# %%
# we have to merge the two data sets, but our data is written in different ways?

# %%
## import homeless shelter data and get sample of 15
dfshelter = pd.read_csv("https://raw.githubusercontent.com/sandeepmj/datasets/main/conditional-conversion/HomelessShelterbyBorough.csv")
dfshelter
# Out:
#      Report Date        Borough  Community District  Census Type  \
# 0       10/31/20          Bronx                   1  Individuals
# 1       10/31/20          Bronx                   2  Individuals
# 2       10/31/20          Bronx                   3  Individuals
# 3       10/31/20          Bronx                   4  Individuals
# 4       10/31/20          Bronx                   5  Individuals
# ...          ...            ...                 ...          ...
# 3181     3/31/23         Queens                  13  Individuals
# 3182     3/31/23         Queens                  14  Individuals
# 3183     3/31/23  Staten Island                   1  Individuals
# 3184     3/31/23  Staten Island                   2  Individuals
# 3185     3/31/23  Staten Island                   3  Individuals
#
#       Adult Family Commercial Hotel  Adult Family Shelter  Adult Shelter  \
# 0                               NaN                 189.0           73.0
# 1                               NaN                 160.0            0.0
# 2                               NaN                 258.0          218.0
# 3                               NaN                   NaN          206.0
# 4                               NaN                 203.0            0.0
# ...                             ...                   ...            ...
# 3181                            NaN                   NaN          131.0
# 3182                            NaN                 321.0          102.0
# 3183                            NaN                   NaN            NaN
# 3184                            NaN                   NaN            NaN
# 3185                            NaN                   NaN            NaN
#
#       Adult Shelter Commercial Hotel  Family Cluster  \
# 0                              140.0            31.0
# 1                                NaN           204.0
# 2                              123.0            62.0
# 3                               99.0           910.0
# 4                                NaN           755.0
# ...                              ...             ...
# 3181                           895.0             NaN
# 3182                           339.0             NaN
# 3183                             NaN             NaN
# 3184                             NaN             NaN
# 3185                             NaN             NaN
#
#       Family with Children Commercial Hotel  Family with Children Shelter
# 0                                      64.0                        1202.0
# 1                                       NaN                         866.0
# 2                                     115.0                        1295.0
# 3                                       NaN                        2134.0
# 4                                       NaN                        1054.0
# ...                                     ...                           ...
# 3181                                    NaN                         832.0
# 3182                                    NaN                         180.0
# 3183                                    NaN                         135.0
# 3184                                  546.0                           NaN
# 3185                                    NaN                           NaN
#
# [3186 rows x 11 columns]

# %%
## get info
dfshelter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3186 entries, 0 to 3185
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Report Date                            3186 non-null   object
#  1   Borough                                3186 non-null   object
#  2   Community District                     3186 non-null   int64
#  3   Census Type                            3186 non-null   object
#  4   Adult Family Commercial Hotel          80 non-null     float64
#  5   Adult Family Shelter                   802 non-null    float64
#  6   Adult Shelter                          1797 non-null   float64
#  7   Adult Shelter Commercial Hotel         1242 non-null   float64
#  8   Family Cluster                         402 non-null    float64
#  9   Family with Children Commercial Hotel  886 non-null    float64
#  10  Family with Children Shelter           2168 non-null   float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 273.9+ KB

# %%
# what we're noticing is that everything is written differently (staten, 1 vs M1 vs Staten 01)

# %%
# this is going to be for homework: using lambda, you're going to be creating new columns to join together the information and get all the same community districts

# %%
dfcensus.head(5)
# Out:
#    Year GeoType   Borough  Community District Number  \
# 0  2020      CD    Queens                        407
# 1  2020      CD  Brooklyn                        311
# 2  2020      CD    Queens                        404
# 3  2020      CD    Queens                        408
# 4  2020      CD    Queens                        411
#
#           Community District Name Total Population  Average household size  \
# 0     Queens Community District 7          269,587                    2.75
# 1  Brooklyn Community District 11          198,870                    2.94
# 2     Queens Community District 4          181,025                    3.24
# 3     Queens Community District 8          161,402                    2.76
# 4    Queens Community District 11          122,211                    2.69
#
#   Children  Latino White non-Hispanic Black non-Hispanic    Asian Other race  \
# 0   45,543  48,845             55,882              5,412  154,404      1,575
# 1   42,380  31,489             72,496              2,353   86,067      1,081
# 2   38,213  93,972              9,329              7,679   65,963      1,692
# 3   32,754  29,486             44,302             18,682   60,413      3,200
# 4   21,612  14,460             41,967              2,641   59,980        779
#
#   Two or more races Total housing units Occupied housing units  \
# 0             3,469             102,836                 97,059
# 1             5,384              71,074                 67,236
# 2             2,390              57,748                 55,202
# 3             5,319              59,385                 56,623
# 4             2,384              47,357                 45,204
#
#   Vacant housing units
# 0                5,777
# 1                3,838
# 2                2,546
# 3                2,762
# 4                2,153

# %%
#Homework

# %%
## recall dfshelter
dfshelter.sample(10)
# Out:
#      Report Date    Borough  Community District  Census Type  \
# 2458     5/31/20  Manhattan                   9  Individuals
# 439      4/30/21   Brooklyn                  10  Individuals
# 1848     6/30/19   Brooklyn                   7  Individuals
# 2002     9/30/19     Queens                  13  Individuals
# 181      3/31/21      Bronx                   5  Individuals
# 672      8/31/21     Queens                   3  Individuals
# 2795     9/30/22   Brooklyn                  11  Individuals
# 891      2/28/22      Bronx                   7  Individuals
# 997      2/28/22     Queens                  12  Individuals
# 1677     1/31/19   Brooklyn                  13  Individuals
#
#       Adult Family Commercial Hotel  Adult Family Shelter  Adult Shelter  \
# 2458                            NaN                   NaN            NaN
# 439                             NaN                   NaN            NaN
# 1848                            NaN                   NaN          185.0
# 2002                            NaN                   NaN            NaN
# 181                             NaN                 199.0            NaN
# 672                             NaN                   NaN            NaN
# 2795                            NaN                   NaN            NaN
# 891                             NaN                   NaN          586.0
# 997                             NaN                 237.0          273.0
# 1677                            NaN                   NaN            NaN
#
#       Adult Shelter Commercial Hotel  Family Cluster  \
# 2458                             NaN             NaN
# 439                              NaN             NaN
# 1848                           100.0             NaN
# 2002                           550.0             NaN
# 181                              NaN           585.0
# 672                            459.0             NaN
# 2795                             NaN             NaN
# 891                              NaN             NaN
# 997                            164.0             NaN
# 1677                             NaN             NaN
#
#       Family with Children Commercial Hotel  Family with Children Shelter
# 2458                                    NaN                         721.0
# 439                                     NaN                           NaN
# 1848                                  475.0                          10.0
# 2002                                  251.0                         846.0
# 181                                     NaN                        1208.0
# 672                                     NaN                         686.0
# 2795                                    NaN                           NaN
# 891                                     NaN                         376.0
# 997                                     NaN                        1359.0
# 1677                                   74.0                           NaN

# %%
# going to have to give the function two arguments 
def convertShelter(cd, borough):
    if cd < 10: 
        str_cd = str(cd)
        str_cd = "0" + str_cd

    else: 
        str_cd = str(cd)

    if borough == "Manhattan":
        str_cd_code = f"M{str_cd}"
    elif borough == "Brooklyn":
        str_cd_code = f"K{str_cd}"
    elif borough == "Bronx":
        str_cd_code = f"B{str_cd}"
    elif borough == "Staten Island":
        str_cd_code = f"S{str_cd}"
    elif borough == "Queens":
        str_cd_code = f"Q{str_cd}"
    else: str_cd_code = "FLAG"
    return str_cd_code


# if borough = manhattan, make it X 
# turn community district into a two digit number

# %%
## test it

test = convertShelter(8, "Brooklyn")
print(test)
# Out:
# K08

# %%
# yay it works!

# %%
# these were my other trials for shelter data 
#dfshelter["updated_cd_shelter"] = dfshelter.apply(lambda x: convertShelter(dfshelter["Community District"],dfshelter["Borough"]), axis = 1)

#(convertShelter(dfshelter["Community District"],dfshelter["Borough"]), axis = 1)
#

# %%
## use on shelter data 
# I had to use chat gpt to help me get here 

dfshelter["updated_cd_shelter"] = dfshelter.apply(
    lambda x: convertShelter(x["Community District"], x["Borough"]), axis=1
)

dfshelter
# Out:
#      Report Date        Borough  Community District  Census Type  \
# 0       10/31/20          Bronx                   1  Individuals
# 1       10/31/20          Bronx                   2  Individuals
# 2       10/31/20          Bronx                   3  Individuals
# 3       10/31/20          Bronx                   4  Individuals
# 4       10/31/20          Bronx                   5  Individuals
# ...          ...            ...                 ...          ...
# 3181     3/31/23         Queens                  13  Individuals
# 3182     3/31/23         Queens                  14  Individuals
# 3183     3/31/23  Staten Island                   1  Individuals
# 3184     3/31/23  Staten Island                   2  Individuals
# 3185     3/31/23  Staten Island                   3  Individuals
#
#       Adult Family Commercial Hotel  Adult Family Shelter  Adult Shelter  \
# 0                               NaN                 189.0           73.0
# 1                               NaN                 160.0            0.0
# 2                               NaN                 258.0          218.0
# 3                               NaN                   NaN          206.0
# 4                               NaN                 203.0            0.0
# ...                             ...                   ...            ...
# 3181                            NaN                   NaN          131.0
# 3182                            NaN                 321.0          102.0
# 3183                            NaN                   NaN            NaN
# 3184                            NaN                   NaN            NaN
# 3185                            NaN                   NaN            NaN
#
#       Adult Shelter Commercial Hotel  Family Cluster  \
# 0                              140.0            31.0
# 1                                NaN           204.0
# 2                              123.0            62.0
# 3                               99.0           910.0
# 4                                NaN           755.0
# ...                              ...             ...
# 3181                           895.0             NaN
# 3182                           339.0             NaN
# 3183                             NaN             NaN
# 3184                             NaN             NaN
# 3185                             NaN             NaN
#
#       Family with Children Commercial Hotel  Family with Children Shelter  \
# 0                                      64.0                        1202.0
# 1                                       NaN                         866.0
# 2                                     115.0                        1295.0
# 3                                       NaN                        2134.0
# 4                                       NaN                        1054.0
# ...                                     ...                           ...
# 3181                                    NaN                         832.0
# 3182                                    NaN                         180.0
# 3183                                    NaN                         135.0
# 3184                                  546.0                           NaN
# 3185                                    NaN                           NaN
#
#      updated_cd_shelter
# 0                   B01
# 1                   B02
# 2                   B03
# 3                   B04
# 4                   B05
# ...                 ...
# 3181                Q13
# 3182                Q14
# 3183                S01
# 3184                S02
# 3185                S03
#
# [3186 rows x 12 columns]

# %%
# reorder columns

# %%
## call columns into list
list(dfshelter.columns)
# Out:
# ['Report Date',
#  'Borough',
#  'Community District',
#  'Census Type',
#  'Adult Family Commercial Hotel',
#  'Adult Family Shelter',
#  'Adult Shelter',
#  'Adult Shelter Commercial Hotel',
#  'Family Cluster',
#  'Family with Children Commercial Hotel',
#  'Family with Children Shelter',
#  'updated_cd_shelter']

# %%
## redorder and call
dfshelter = dfshelter[['Report Date',
 'Borough',
 'Community District',
 'Census Type',
                       'updated_cd_shelter',
 'Adult Family Commercial Hotel',
 'Adult Family Shelter',
 'Adult Shelter',
 'Adult Shelter Commercial Hotel',
 'Family Cluster',
 'Family with Children Commercial Hotel',
 'Family with Children Shelter',
 ]]

# %%
dfshelter
# Out:
#      Report Date        Borough  Community District  Census Type  \
# 0       10/31/20          Bronx                   1  Individuals
# 1       10/31/20          Bronx                   2  Individuals
# 2       10/31/20          Bronx                   3  Individuals
# 3       10/31/20          Bronx                   4  Individuals
# 4       10/31/20          Bronx                   5  Individuals
# ...          ...            ...                 ...          ...
# 3181     3/31/23         Queens                  13  Individuals
# 3182     3/31/23         Queens                  14  Individuals
# 3183     3/31/23  Staten Island                   1  Individuals
# 3184     3/31/23  Staten Island                   2  Individuals
# 3185     3/31/23  Staten Island                   3  Individuals
#
#      updated_cd_shelter  Adult Family Commercial Hotel  Adult Family Shelter  \
# 0                   B01                            NaN                 189.0
# 1                   B02                            NaN                 160.0
# 2                   B03                            NaN                 258.0
# 3                   B04                            NaN                   NaN
# 4                   B05                            NaN                 203.0
# ...                 ...                            ...                   ...
# 3181                Q13                            NaN                   NaN
# 3182                Q14                            NaN                 321.0
# 3183                S01                            NaN                   NaN
# 3184                S02                            NaN                   NaN
# 3185                S03                            NaN                   NaN
#
#       Adult Shelter  Adult Shelter Commercial Hotel  Family Cluster  \
# 0              73.0                           140.0            31.0
# 1               0.0                             NaN           204.0
# 2             218.0                           123.0            62.0
# 3             206.0                            99.0           910.0
# 4               0.0                             NaN           755.0
# ...             ...                             ...             ...
# 3181          131.0                           895.0             NaN
# 3182          102.0                           339.0             NaN
# 3183            NaN                             NaN             NaN
# 3184            NaN                             NaN             NaN
# 3185            NaN                             NaN             NaN
#
#       Family with Children Commercial Hotel  Family with Children Shelter
# 0                                      64.0                        1202.0
# 1                                       NaN                         866.0
# 2                                     115.0                        1295.0
# 3                                       NaN                        2134.0
# 4                                       NaN                        1054.0
# ...                                     ...                           ...
# 3181                                    NaN                         832.0
# 3182                                    NaN                         180.0
# 3183                                    NaN                         135.0
# 3184                                  546.0                           NaN
# 3185                                    NaN                           NaN
#
# [3186 rows x 12 columns]
